# %%
import pandas as pd

# %%
df = pd.read_csv('res_purchase_card_(pcard)_fiscal_year_2014_3pcd-aiuu.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442458 entries, 0 to 442457
# Data columns (total 11 columns):
# Year-Month                      442458 non-null int64
# Agency Number                   442458 non-null int64
# Agency Name                     442458 non-null object
# Cardholder Last Name            442458 non-null object
# Cardholder First Initial        442458 non-null object
# Description                     442458 non-null object
# Amount                          442458 non-null float64
# Vendor                          442458 non-null object
# Transaction Date                442458 non-null object
# Posted Date                     442458 non-null object
# Merchant Category Code (MCC)    442458 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 37.1+ MB

# %%
df.head()
# Out:
#    Year-Month  Agency Number                Agency Name Cardholder Last Name  \
# 0      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 1      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 2      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 3      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 4      201307           1000  OKLAHOMA STATE UNIVERSITY        Mauro-Herrera
#
#   Cardholder First Initial                   Description  Amount  \
# 0                        C              GENERAL PURCHASE  890.00
# 1                        C                  ROOM CHARGES  368.96
# 2                        J              GENERAL PURCHASE  165.82
# 3                        T              GENERAL PURCHASE   96.39
# 4                        M  HAMMERMILL COPY PLUS COPY EA  125.96
#
#            Vendor        Transaction Date             Posted Date  \
# ...

# %%
from collections import Counter
# Counter(df['Agency Number'])
groups = df.groupby(by = ['Agency Number'])
all_group = df['Agency Number'].unique()
print('all_group',all_group)
groups.get_group(1000)
# Out:
# all_group [ 1000  2000  2200  2500  3900  4000  4500  4700  4900  5500  6000  6500
#   9000  9200 10500 12500 12700 13100 14500 15000 16000 18500 19000 20400
#  21500 22000 24000 24100 26500 26900 27000 29000 29200 29600 29800 30000
#  30500 30600 30800 30900 31000 31500 32000 32600 34000 34200 34500 34600
#  35000 35300 36900 38500 39000 40000 40500 41000 41500 41600 42000 42200
#  43000 43500 44600 45000 45200 47700 48000 50900 51000 51500 53000 53100
#  55700 56000 56600 56800 57000 58200 58500 58800 60500 60600 61000 61900
#  62500 62900 63200 63300 63500 64500 65000 66500 67000 67700 69500 71500
#  74000 75000 76000 77000 77200 79000 80000 80500 80700 81500 83000 83500
#  87500 88000 92200 98000 39100 86500 27500 56300]
#         Year-Month  Agency Number                Agency Name  \
# 0           201307           1000  OKLAHOMA STATE UNIVERSITY
# 1           201307           1000  OKLAHOMA STATE UNIVERSITY
# 2           201307           1000  OKLAHOMA STATE UNIVERSITY
# ...

# %%
Counter(df['Agency Name'])
# Out:
# Counter({'ARDMORE HIGHER EDUCATION CENTER': 59,
#          'ATTORNEY GENERAL': 1495,
#          'BD. OF CHEM. TEST ALCOHOL/DRUG': 82,
#          'BD. OF EXAM. FOR LT CARE ADMIN': 17,
#          'BD. OF EXAM. FOR LT CARE ADMIN.': 15,
#          'BD. OF MED. LICENSURE & SUPV.': 880,
#          'BD. OF MEDICOLEGAL INVESTIGATIONS': 717,
#          'BD. OF PRIV. VOCATIONAL SCHOOLS': 1,
#          'BD. OF VETERINARY MED. EXAM.': 60,
#          'BOARD OF DENTISTRY': 68,
#          'BOLL WEEVIL ERADICATION ORG.': 170,
#          'CAPITOL IMPROVEMENT AUTHORITY': 27,
#          'COMM. OF THE LAND OFFICE': 323,
#          'COMM. ON CONSUMER CREDIT': 979,
#          'COMMISSION ON CHILDREN AND YOUTH': 37,
#          'COMPSOURCE OKLAHOMA': 1566,
#          'CONSERVATION COMMISSION': 632,
#          'CORPORATION COMMISSION': 908,
#          'COSMETOLOGY BOARD': 200,
#          'COUNCIL ON LAW ENFC. ED. & TRNG.': 538,
#          'DEPARTMENT OF AGRICULTURE': 3085,
# ...

# %%
Counter(df['Merchant Category Code (MCC)'])
# Out:
# Counter({' ': 3,
#          'ACCOUNTING,AUDITING AND BOOKKEEPING SERVICES': 94,
#          'ADVANTAGE RENT A CAR': 2,
#          'ADVERTISING SERVICES': 1520,
#          'AER LINGUS': 7,
#          'AEROLINEAS ARGENTINAS': 4,
#          'AEROMEXICO': 4,
#          'AGRICULTURAL COOPERATIVES': 487,
#          'AIR BERLIN': 4,
#          'AIR CANADA': 10,
#          'AIR CHINA': 14,
#          'AIR CONDITIONING AND REFRIGERATION REPAIR SHOPS': 156,
#          'AIR FRANCE': 22,
#          'AIR INDIA': 6,
#          'AIR NEW ZEALAND LTD. INTERNATIONAL': 4,
#          'AIRLINES AND AIR CARRIERS': 6180,
#          'AIRPORTS,FLYING FIELDS,AND AIRPORT TERMINALS': 22,
#          'AIRTRAN AIRWAYS': 56,
#          'ALAMO RENT-A-CAR': 5,
#          'ALASKA AIRLINES INC.': 45,
#          'ALITALIA': 3,
#          'ALOFT HOTELS': 25,
#          'AMBULANCE SERVICES': 1,
#          'AMERICAN AIRLINES': 12015,
#          'AMERICAS BEST VALUE INN': 48,
#          'AMERICINN': 33,
# ...

# %%
Counter(df['Vendor'])
# Out:
# Counter({'NACAS': 9,
#          'SHERATON HOTEL': 159,
#          'SEARS.COM 9300': 118,
#          'WAL-MART #0137': 2548,
#          'STAPLES DIRECT': 1450,
#          'KYOCERA DOCUMENT SOLUTION': 8,
#          'DAYLIGHT DONUTS': 28,
#          'UFIRST  LAUNDRY SVCS': 98,
#          'AT&T DATA': 2622,
#          "RANDY'S FOODS": 57,
#          'DEARINGER PRINTING & TROP': 791,
#          'GIDDINGS MACHINE CO.': 7,
#          'LOWES #00241': 4231,
#          'OK DEPT OF VO-TECH ED': 764,
#          'TFS THERMOASHEVILLE': 29,
#          'WESTERN EQUIPMENT ALVA': 3,
#          'HOBBY-LOBBY #0005': 657,
#          'WAL-MART #0121': 411,
#          'WESTIN DENVER DOWNTOWN': 7,
#          'BIO RAD': 306,
#          'LOCKE SUPPLY - STILLWATER': 314,
#          'NAPA AUTO PARTS': 1200,
#          'AFFYMETRIX, INC': 11,
#          'EXPERIAN': 4,
#          'AIRGAS CENTRAL': 2682,
#          'UCR - SPARE PARTS WAREHOU': 3,
#          'OK MEDICAL BOARD': 63,
#          'TRAK1 TECHN': 3,
# ...
